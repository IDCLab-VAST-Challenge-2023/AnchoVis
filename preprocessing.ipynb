# %%
import json
from collections import Counter

import numpy as np
import networkx as nx
import pandas as pd
from scipy.cluster.hierarchy import linkage, dendrogram
from IPython.display import display

# %% [markdown]
# # Preprocess raw data

# %%
with open("data/MC3.json", 'r'):
    mc3 = json.load(open("data/MC3.json", 'r'))

# %%
nodes = [
    {
        'id': node['id'][0],
        'country': node['country'][0],
        'product_services': node['product_services'][0] if len(node['product_services']) > 0 else "Unknown",
        'revenue_omu': node['revenue_omu'][0] if 'revenue_omu' in node else "None",
        'type': node['type'][0]
    }
    for node in mc3['nodes']
]
links = [
    {
        'source': src,
        'target': link['target'][0],
        'type': link['type'][0],
    }
    for link in mc3['links']
    for src in link['source']
]
df_nodes = pd.DataFrame(nodes)
df_links = pd.DataFrame(links)

# %%
display(df_nodes)
df_links
# Out:
#                                          id     country  \
# 0                                 Jones LLC          ZH
# 1                   Coleman, Hall and Lopez          ZH
# 2      Aqua Advancements Sashimi SE Express     Oceanus
# 3                 Makumba Ltd. Liability Co  Utoporiana
# 4                Taylor, Taylor and Farrell          ZH
# ...                                     ...         ...
# 27617            Johnson, Lee and Rodriguez          ZH
# 27618           Bowman, Rollins and Griffin          ZH
# 27619                          Hardin Group          ZH
# 27620             Crane, Joyce and Jennings          ZH
# 27621                        Smith and Sons          ZH
#
#                                         product_services     revenue_omu  \
# 0                                            Automobiles   310612303.447
# 1                Passenger cars, trucks, vans, and buses  162734683.9969
# 2      Holding firm whose subsidiaries are engaged in...  115004666.6728
# 3      Car service, car parts and accessories, automo...   90986412.5191
# 4      Fully electric vehicles (EVs) and electric veh...   81466666.6728
# ...                                                  ...             ...
# 27617                                            Unknown            None
# 27618                                            Unknown            None
# 27619                                            Unknown            None
# 27620                                            Unknown            None
# 27621                                            Unknown            None
#
#                    type
# 0               Company
# 1               Company
# 2               Company
# 3               Company
# 4               Company
# ...                 ...
# 27617  Company Contacts
# 27618  Company Contacts
# 27619  Company Contacts
# 27620  Company Contacts
# 27621  Company Contacts
#
# [27622 rows x 5 columns]
#                                                   source              target  \
# 0      Lake Chad  Catchers Limited Liability Company ...         Erin Flores
# 1      Lake Chad  Catchers Limited Liability Company ...           Linda Lee
# 2      Lake Chad  Catchers Limited Liability Company ...      Sharon Coleman
# 3      Lake Chad  Catchers Limited Liability Company ...         John Rivera
# 4      Lake Chad  Catchers Limited Liability Company ...   Stephen Carpenter
# ...                                                  ...                 ...
# 27166                                      Martinez-Diaz         Mark Thomas
# 27167                                         Garcia Inc  Christopher Wagner
# 27168                        Potter, Williams and Peters    Mr. Troy Shields
# 27169                                      Tucker-Willis        Robert James
# 27170                          Sanchez, Welch and Harvey     Kimberly Flores
#
#                    type
# 0      Beneficial Owner
# 1      Beneficial Owner
# 2      Beneficial Owner
# 3      Beneficial Owner
# 4      Beneficial Owner
# ...                 ...
# 27166  Company Contacts
# 27167  Company Contacts
# 27168  Company Contacts
# 27169  Company Contacts
# 27170  Company Contacts
#
# [27171 rows x 3 columns]

# %% [markdown]
# #### Merge Duplicated Links

# %%
df_unique_links = df_links.drop_duplicates(subset=['source', 'target'])
df_unique_links['weight'] = df_unique_links.apply(lambda x: len(df_links[(df_links['source'] == x['source']) & (df_links['target'] == x['target'])]), axis=1)
# Out:
# /var/folders/9n/0sr5b2sn26z6qnbv7h2_9b9w0000gn/T/ipykernel_1700/4246369611.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unique_links['weight'] = df_unique_links.apply(lambda x: len(df_links[(df_links['source'] == x['source']) & (df_links['target'] == x['target'])]), axis=1)

# %% [markdown]
# #### Merge Duplicated Nodes

# %%
# merge duplicated nodes
nodes_id_count = Counter(df_nodes['id'])
unique_nodes_id = list(nodes_id_count.keys())
unique_nodes = [
    {   
        "id": unique_node,
        "country": df_nodes[df_nodes['id'] == unique_node]['country'].values[0],
        "product_services": list(set(df_nodes[df_nodes['id'] == unique_node]['product_services'])),
        "revenue_omu": list(set(df_nodes[df_nodes['id'] == unique_node]['revenue_omu'])),
        "type": dict(Counter(df_nodes[df_nodes['id'] == unique_node]['type']))
    }   
    for unique_node in unique_nodes_id
]
unique_nodes
# Out:
# [{'id': 'Jones LLC',
#   'country': 'ZH',
#   'product_services': ['Automobiles', 'Unknown'],
#   'revenue_omu': ['None', 310612303.447],
#   'type': {'Company': 1, 'Beneficial Owner': 5, 'Company Contacts': 5}},
#  {'id': 'Coleman, Hall and Lopez',
#   'country': 'ZH',
#   'product_services': ['Passenger cars, trucks, vans, and buses'],
#   'revenue_omu': [162734683.9969],
#   'type': {'Company': 1}},
#  {'id': 'Aqua Advancements Sashimi SE Express',
#   'country': 'Oceanus',
#   'product_services': ['Holding firm whose subsidiaries are engaged in the businesses of refining and chemicals, process and pollution control equipment, minerals, fertilizers, polymers and fibers, commodity trading and services, forest and consumer products, and ranching'],
#   'revenue_omu': [115004666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Makumba Ltd. Liability Co',
#   'country': 'Utoporiana',
#   'product_services': ['Car service, car parts and accessories, automotive technology, diagnostics for repair shops, antilock braking and fuel-injection systems, auto electronics, starters, and alternators; Home (power tools for DIY enthusiasts, garden tools, household appliances, heating and warm water); and industry and trade (communication services, power tools for professional, sensors and foundry - MEMS, security systems, packaging technology)'],
#   'revenue_omu': [90986412.5191],
#   'type': {'Company': 1}},
#  {'id': 'Taylor, Taylor and Farrell',
#   'country': 'ZH',
#   'product_services': ['Fully electric vehicles (EVs) and electric vehicle powertrain components'],
#   'revenue_omu': [81466666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Harmon, Edwards and Bates',
#   'country': 'ZH',
#   'product_services': ['Discount supermarket; Variety of food and non-food products'],
#   'revenue_omu': [75070434.9897],
#   'type': {'Company': 1}},
#  {'id': 'Punjab s Marine conservation',
#   'country': 'Riodelsol',
#   'product_services': ['Beef, pork, chicken, and lamb by-products; convenience food products; pet food and concentrates; and bresaola; Electric power; provision of cattle fattening and transportation services; management of industrial residue; production and commercialization of steel cans, plastic resin, soap base, soap bar, biodiesel, glycerin, fatty acid, collagen, and wrapper, as well as wet blue, semi-finished, and finished leather products; and purchase and sale of soybean; Cooked frozen meat; logistic and warehousing operations; and distribution center and harbor, waste management and recycling, tallow, palm oil, caustic soda, stearin, and dog biscuits business'],
#   'revenue_omu': [72167572.0026],
#   'type': {'Company': 1}},
#  {'id': 'Assam   Limited Liability Company',
#   'country': 'Utoporiana',
#   'product_services': ['Unknown',
#    'Power and Gas segment (gas and steam turbines, generators for gas or steam power plants, compressor trains, integrated power plant solutions, and instrumentation and control systems for power generation, and producing and transporting oil and gas); Wind Power and Renewables segment (geared and direct drive wind turbines for onshore and offshore applications; and engages in the hydro power business); Energy Management (offers products, systems, solutions, software, and services for transmitting and distributing power, and developing intelligent grid infrastructure); Building Technologies segment (provides automation technologies and digital services for fire safety, security, building automation, heating, ventilation, air conditioning, and energy management); Mobility segment (passenger and freight transportation, including rail vehicles and automation systems, and electrification systems; road traffic technology, IT solution, and related services; and consulting, planning, financing, construction, service, and mobility system services); Digital Factory segment (provides products and system solutions for manufacturing industries; and lifecycle and data-driven services); Process Industries and Drives segment (couplings, gears, motors and converters, process instrumentation systems, process analytics devices, wired and wireless communication, industrial identification and power supplies, and decentralized control systems and industrial software; and application-specific systems and solutions); Healthineers segment (provides medical technology and software solutions; and clinical consulting and training); Financial Services segment (offers leasing solutions and equipment; and debt and equity investment products)'],
#   'revenue_omu': [20666.6728, 72162317.2658],
#   'type': {'Company': 2}},
#  {'id': 'Ianira Starfish Sagl Import',
#   'country': 'Rio Isla',
#   'product_services': ['Light commercial vehicles, passenger cars, buses and trucks, forklifts, and related components'],
#   'revenue_omu': [68832979.2399],
#   'type': {'Company': 1}},
#  {'id': 'Moran, Lewis and Jimenez',
#   'country': 'ZH',
#   'product_services': ['Automobiles, trucks, steel products, industrial machinery, chemical products, and energy'],
#   'revenue_omu': [65592905.5342],
#   'type': {'Company': 1}},
#  {'id': 'Lee-Coleman',
#   'country': 'ZH',
#   'product_services': ['Diagnostic equipment and pharmaceuticals, agricultural products such as crop protection and animal health, and specialty materials such as plastics and synthetic rubber; Health care, Material Science and Crop science'],
#   'revenue_omu': [55349447.5191],
#   'type': {'Company': 1}},
#  {'id': 'Oceanic Explorers Plc Salt spray',
#   'country': 'Oceanus',
#   'product_services': ['Internet Protocol based networking products and services'],
#   'revenue_omu': [51561666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Saltwater Sisters AS Marine life',
#   'country': 'Coralmarica',
#   'product_services': ["Food and daily household needs products, general merchandise products, organic products, adult apparel, children's wear and accessories, and house ware products, such as kitchen, bed and bath, and home decor"],
#   'revenue_omu': [41542564.0136],
#   'type': {'Company': 1}},
#  {'id': 'The Sea Turtle Company',
#   'country': 'Oceanus',
#   'product_services': ['Grocery products'],
#   'revenue_omu': [40362666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Smith, Mathews and Waters',
#   'country': 'ZH',
#   'product_services': ['Vessels for the transport of various goods, such as cargo with oversized dimensions and dangerous goods; and general, non-containerized, temperature controlled cargo; Provides stowage consultation and customs clearance, as well as e-business solutions for information sharing; and cargo distribution, storage, commissioning, and insurance services'],
#   'revenue_omu': [36901222.7903],
#   'type': {'Company': 1}},
#  {'id': 'Mar de la Aventura Pier CJSC Logistics',
#   'country': 'Isliandor',
#   'product_services': ['Computer notebook and electronic products; Personal digital assistant (PDA) products'],
#   'revenue_omu': [34971767.8821],
#   'type': {'Company': 1}},
#  {'id': 'Fisher Group',
#   'country': 'ZH',
#   'product_services': ['Steel (marketing of API (active pharmaceutical ingredient) materials, automotive flat products, and electrical flat products); metal (distribution of iron ore pellet, scrap, and steel items including slab, billet, and shape steel; and raw materials for basic industry); machinery (marketing of industrial and heavy machinery and equipment, as well as defense-related commodities and paper making equipment); automotive and component (marketing of ball joint, aluminum wheel, and automobile seat parts, among others); commodity (marketing of grains, cotton, construction materials, and petrochemical products); media and electronics (marketing of LCD (liquid crystal display) TV and monitor, PDP (plasma display panel) TV, digital versatile disc, telecommunication devices, and other home appliances); chemical (trading of plastic resins, polyester raw materials, tire raw materials, fertilizers, and fine chemicals, among others); textile (trading of fiber and yarn as well as leather); and distribution (operation and management of department stores in Korea)',
#    'Unknown'],
#   'revenue_omu': ['None', 29981457.4744],
#   'type': {'Company': 1, 'Beneficial Owner': 4, 'Company Contacts': 2}},
#  {'id': 'South Yacht AS Investment',
#   'country': 'Rio Isla',
#   'product_services': ['Advanced electronic and electrical products, spanning information and communications equipment and systems, Internet-based solutions and services, electronic components and materials, power systems, industrial and social infrastructure systems, and household appliances'],
#   'revenue_omu': [27684153.4724],
#   'type': {'Company': 1}},
#  {'id': 'Mar de Cristalino Ges.m.b.H.',
#   'country': 'Rio Isla',
#   'product_services': ['Full line of air-conditioning systems and refrigerants'],
#   'revenue_omu': [25405860.8648],
#   'type': {'Company': 1}},
#  {'id': 'Uttar Pradesh Sea  Company Seafoam',
#   'country': 'Osterivaria',
#   'product_services': ['Wide range of consumer products'],
#   'revenue_omu': [24120481.1023],
#   'type': {'Company': 1}},
#  {'id': 'Morales, Young and Taylor',
#   'country': 'ZH',
#   'product_services': ['Processed foods and other food products'],
#   'revenue_omu': [23739782.3158],
#   'type': {'Company': 1}},
#  {'id': 'Morgan LLC',
#   'country': 'ZH',
#   'product_services': ['Animal feed, animal breeding and animal farming; meat processing; Semi-cooked meat and fully-cooked meat; food products and ready meal products',
#    'Unknown'],
#   'revenue_omu': ['None', 17939781.4469],
#   'type': {'Company': 1, 'Beneficial Owner': 2}},
#  {'id': 'Okavango River  NV Marine life',
#   'country': 'Kondanovia',
#   'product_services': ['Batteries'],
#   'revenue_omu': [15884149.6701],
#   'type': {'Company': 1}},
#  {'id': 'Kennedy-Sanchez',
#   'country': 'ZH',
#   'product_services': ['Glass products, electronics and display products, chemicals products, and other products'],
#   'revenue_omu': [15381123.0587],
#   'type': {'Company': 1}},
#  {'id': 'Hopkins LLC',
#   'country': 'ZH',
#   'product_services': ['Operates tramp (panamax) vessels for transporting various bulk cargoes, such as grain, coal, iron ore, etc. Ranging from 60,000 DWT to 80,000 DWT; and tramp (handymax) vessels for transporting fertilizers from the North Pacific, the Middle East, and Continent to Australia, as well iron ore, salt, grain, coal, and silica sand from Australia to India, P.G., and the Far East; Operates a fleet of four VLCCs and two suezmax crude tankers; seven MRs and two chemical tankers for transporting gasoline, gas oil, naphtha, methanol, and palm oils; and tramp (cape) vessels for the transportation of dry cargoes, including coal and iron ore with capacities ranging from 100,000 DWT to 200,000 DWT; Offers transportation services with bulk cargoes, cement, iron ore, coal, scrap, petcoke, sulphur, and hbi; sugar transportation from Australia, Guatemala, and South Africa to the Far East; and conventional liner services throughout various ports and countries, as well as heavy-lift services; Provides dangerous and over-sized cargo services',
#    'Unknown'],
#   'revenue_omu': ['None', 14667942.4095],
#   'type': {'Company': 1, 'Company Contacts': 1}},
#  {'id': 'Omo River  Ocean Incorporated Marine sanctuary',
#   'country': 'Rio Isla',
#   'product_services': ['Office automation equipment'],
#   'revenue_omu': [14404528.5671],
#   'type': {'Company': 1}},
#  {'id': 'OceanFront Foods SRL Line',
#   'country': 'Alverovia',
#   'product_services': ['Flat steel'],
#   'revenue_omu': [14201069.6737],
#   'type': {'Company': 1}},
#  {'id': 'Lake Tana  N.V. Enterprises',
#   'country': 'Rio Isla',
#   'product_services': ['Manufacture and sale of chemicals worldwide'],
#   'revenue_omu': [13279495.8262],
#   'type': {'Company': 1}},
#  {'id': 'Reed LLC',
#   'country': 'ZH',
#   'product_services': ['Empty hard gelatin capsules and related products',
#    'Produces power tools, outdoor power equipment, floor care appliances, solar powered lighting and electronic measuring tools',
#    'Unknown'],
#   'revenue_omu': ['None', 13272100.6728, 14525.7733],
#   'type': {'Company': 2, 'Beneficial Owner': 1}},
#  {'id': 'Sailors and Surfers ОАО Delivery',
#   'country': 'Galduzim',
#   'product_services': ['Fashion clothing'],
#   'revenue_omu': [12665898.365],
#   'type': {'Company': 1}},
#  {'id': 'Ob River - Co Express',
#   'country': 'Oceanus',
#   'product_services': ['Food products'],
#   'revenue_omu': [11504666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Telangana  Wakame CJSC United',
#   'country': 'Gavanovia',
#   'product_services': ['Perfumes, cosmetics and other toilet preparations'],
#   'revenue_omu': [11352673.6142],
#   'type': {'Company': 1}},
#  {'id': 'Reyes-Lee',
#   'country': 'ZH',
#   'product_services': ['Produces and sells both commercial vehicles and passenger vehicles, including mini passenger cars (Chevrolet Spark), mini commercial vans and mini-trucks (Wuling brand), mini single cab pickups, and mini double cab pickups'],
#   'revenue_omu': [10961937.248],
#   'type': {'Company': 1}},
#  {'id': 'Cox, Williams and Jones',
#   'country': 'ZH',
#   'product_services': ['Offers a wide range of olefins, including ethylene and propylene, C4 fraction, and cracked fuel; organic chemicals, such as vinyl acetate monomer, ethyl acetate, and ester resins, as well as acetaldehyde, acetic acid, and allyl alcohol'],
#   'revenue_omu': [10503128.4803],
#   'type': {'Company': 1}},
#  {'id': 'Beachcombers Nautical Plc Carriers',
#   'country': 'Oceanus',
#   'product_services': ['Products via mail order houses'],
#   'revenue_omu': [9891666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Tamil Nadu  Market Corp',
#   'country': 'Utoporiana',
#   'product_services': ['Provides agriculture and turf equipment, and related service parts, including large, medium, and utility tractors; loaders; combines, corn pickers, cotton and sugarcane harvesters, and related front-end equipment and sugarcane loaders; and tillage, seeding, and application equipment, such as sprayers, nutrient management, and soil preparation machinery; Provides hay and forage equipment comprising self-propelled forage harvesters and attachments, balers, and mowers; and riding lawn equipment and walk-behind mowers, golf course equipment, utility vehicles, and commercial mowing equipment. In addition, this segment offers integrated agricultural management systems technology and solutions; precision agricultural irrigation equipment and supplies; landscape and nursery products; and other outdoor power products; Provides backhoe loaders that are used in construction, earthmoving, material handling, and timber harvesting applications; crawler dozers and loaders; four-wheel-drive loaders; excavators; motor graders; articulated dump trucks; landscape loaders; skid-steer loaders; and log skidders, feller bunchers, log loaders, log forwarders, log harvesters, and related attachments'],
#   'revenue_omu': [9304674.2644],
#   'type': {'Company': 1}},
#  {'id': 'Adkins, Garcia and Perkins',
#   'country': 'ZH',
#   'product_services': ['Hydraulic and thermal electric power, and distributes electric power to other electric companies through its electronic power lines and frequency transformer stations'],
#   'revenue_omu': [8865949.8345],
#   'type': {'Company': 1}},
#  {'id': 'Norwegian Fjord  S.A. de C.V. Brothers',
#   'country': 'Utoporiana',
#   'product_services': ['Develops innovative products and solutions in chemical and semiconductor sectors'],
#   'revenue_omu': [8836217.0955],
#   'type': {'Company': 1}},
#  {'id': "Neptune's Harvest LC Transport",
#   'country': 'Riodelsol',
#   'product_services': ['Frozen whole and cut chickens, partridges, and quail; and frozen pork and beef cuts, such as loins and ribs, and whole carcasses; Marinated frozen whole and cut chickens, roosters, and turkeys; specialty meats, such as sausages, ham products, bologna, frankfurters, salamis, bacon, chicken sausages, chicken hot dogs, chicken bologna, and other smoked products; frozen processed meats comprising hamburgers, steaks, breaded meat products, kibes and meatballs, and frozen processed vegetarian foods; frozen prepared entrees consisting of lasagnas and pizzas, vegetables, cheese bread, pies, and pastries; dairy products, such as cheeses, powdered milk, and yogurts; juices, soy milk, and soy juices; and margarine; Pasteurized and ultra-heat treatment milk'],
#   'revenue_omu': [8726578.5937],
#   'type': {'Company': 1}},
#  {'id': 'Hill-Harris',
#   'country': 'ZH',
#   'product_services': ['Financial institutions (private banking, personal financial services, trust services, commercial and corporate banking, corporate finance, investment banking, capital market activities, treasury services, asset management, venture capital management, general insurance, and life assurance services; and travel, leasing, property development and management, hotel operations and general trading)'],
#   'revenue_omu': [8686802.4037],
#   'type': {'Company': 1}},
#  {'id': 'OceanicHarvest Ltd. Liability Co Family',
#   'country': 'Puerto Sol',
#   'product_services': ['Electricity'],
#   'revenue_omu': [8237703.6674],
#   'type': {'Company': 1}},
#  {'id': 'Stewart, Edwards and Leonard',
#   'country': 'ZH',
#   'product_services': ['Plastic-related products'],
#   'revenue_omu': [8205988.6405],
#   'type': {'Company': 1}},
#  {'id': 'Victoria Falls   Limited Liability Company',
#   'country': 'Rio Isla',
#   'product_services': ['Domestic and international air and ocean freight forwarding services; Customs clearance, warehousing, trucking, temporary staffing, insurance agency, property management, and packaging services'],
#   'revenue_omu': [8014805.9974],
#   'type': {'Company': 1}},
#  {'id': 'Colon, West and Powell',
#   'country': 'ZH',
#   'product_services': ['Operates Wills Lifestyle stores, including approximately 400 outlets, and 6 exclusive boutiques; and approximately 350 John Players stores and 750 outlets in departmental stores and multi-brand outlets'],
#   'revenue_omu': [8007623.0298],
#   'type': {'Company': 1}},
#  {'id': 'Caracola del Este BV',
#   'country': 'Rio Isla',
#   'product_services': ['High-grade metal products and materials, electronics and IT devices, high-grade functional components and equipment',
#    'Unknown'],
#   'revenue_omu': [13848.1599, 7744642.584],
#   'type': {'Company': 2}},
#  {'id': 'Coral Reef CJSC Import',
#   'country': 'Rio Isla',
#   'product_services': ['Information Equipment, Optics, Medical and Graphic, Measuring Machine, and Photo Imaging'],
#   'revenue_omu': [7534879.5007],
#   'type': {'Company': 1}},
#  {'id': 'Caracola del Mar NV Family',
#   'country': 'Rio Isla',
#   'product_services': ['Canned, frozen and other processed convenience foods, together with meats, animal feed and fish byproducts'],
#   'revenue_omu': [7085565.7508],
#   'type': {'Company': 1}},
#  {'id': 'Meyer-Ho',
#   'country': 'ZH',
#   'product_services': ['Unknown'],
#   'revenue_omu': [7000282.8175],
#   'type': {'Company': 1}},
#  {'id': 'Long and Sons',
#   'country': 'ZH',
#   'product_services': ['Providing executive, legislative, and other general government support',
#    'Unknown'],
#   'revenue_omu': ['None', 6932730.7751],
#   'type': {'Company': 1, 'Beneficial Owner': 1, 'Company Contacts': 1}},
#  {'id': 'Jenkins Group',
#   'country': 'ZH',
#   'product_services': ['Manufacture and marketing of communication products, electronic equipment and electronic components, as well as management, development and letting of real estate',
#    'Specializes in producing processed frozen cod and frozen squid, processed sea cucumbers, sea eggs, and others',
#    'Unknown'],
#   'revenue_omu': [80248.5841, 6721268.9403, 'None'],
#   'type': {'Company': 2, 'Beneficial Owner': 1, 'Company Contacts': 2}},
#  {'id': 'Turkish Mussels S.A. de C.V. Transport',
#   'country': 'Kondanovia',
#   'product_services': ['Steel products'],
#   'revenue_omu': [6720618.682],
#   'type': {'Company': 1}},
#  {'id': 'Bahía de Plata Jetty',
#   'country': 'Rio Isla',
#   'product_services': ['Plastic and metal zippers; plastic hardware including buckles, strap adjusters, loops, D rings, snap hooks, cord stoppers, and cord ends; fabric hook and loop fasteners; snaps and buttons; rivets and burrs; and eyelet washers; Aluminum architectural products (windows, curtain walls, sliding doors)'],
#   'revenue_omu': [6516260.1642],
#   'type': {'Company': 1}},
#  {'id': 'Mason Ltd',
#   'country': 'ZH',
#   'product_services': ['Automobile tires'],
#   'revenue_omu': [6508571.4934],
#   'type': {'Company': 1}},
#  {'id': 'Poole-Moore',
#   'country': 'ZH',
#   'product_services': ['Management, selling, and buying of real estate properties'],
#   'revenue_omu': [6495455.3332],
#   'type': {'Company': 1}},
#  {'id': 'The Sea Lion NV Marine biology',
#   'country': 'Oceanus',
#   'product_services': ['One- to five-day freight shipping service'],
#   'revenue_omu': [6264743.6728],
#   'type': {'Company': 1}},
#  {'id': 'Water World GmbH & Co. KG',
#   'country': 'Oceanus',
#   'product_services': ['Denim jeans and other apparels'],
#   'revenue_omu': [6173266.6728],
#   'type': {'Company': 1}},
#  {'id': 'Saharan Oasis  S.A. de C.V.',
#   'country': 'Oceanus',
#   'product_services': ['Food products'],
#   'revenue_omu': [6161666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Mar de la Felicidad Rybachit',
#   'country': 'Marebak',
#   'product_services': ['Railway products and equipment'],
#   'revenue_omu': [6094773.4228],
#   'type': {'Company': 1}},
#  {'id': 'Rollins, Mercado and Miller',
#   'country': 'ZH',
#   'product_services': ['Pharmaceuticals; Warehousing; Fresh and frozen sea foods'],
#   'revenue_omu': [5672003.5824],
#   'type': {'Company': 1}},
#  {'id': 'Estrella de la Costa Ltd Trawler',
#   'country': 'Rio Isla',
#   'product_services': ['Seal products, industrial mechanical parts, hydraulic and pneumatic equipment, nuclear power equipment, synthetic chemical products, and electronic and various other products'],
#   'revenue_omu': [5580704.5578],
#   'type': {'Company': 1}},
#  {'id': 'Alvarez-Cabrera',
#   'country': 'ZH',
#   'product_services': ['Flat products (coils, strips, sheets), both carbon and pre-painted (PPGI) steel and carbon steel welded tubes'],
#   'revenue_omu': [5215309.9125],
#   'type': {'Company': 1}},
#  {'id': 'Senegal Coast  Kga Freight',
#   'country': 'Rio Isla',
#   'product_services': ['Copper foil, battery materials, engineered metal powders, rare metals, micro circuits, zinc, copper, precious metals, door locks for automobiles, and sensors'],
#   'revenue_omu': [5179062.3791],
#   'type': {'Company': 1}},
#  {'id': 'Wilson-Matthews',
#   'country': 'ZH',
#   'product_services': ['Specialty pharmaceuticals and active pharmaceutical ingredients (APIs)'],
#   'revenue_omu': [5158710.4006],
#   'type': {'Company': 1}},
#  {'id': 'Mar de la Felicidad Incorporated',
#   'country': 'Sol y Oceana',
#   'product_services': ['Flat and long steel products', 'Unknown'],
#   'revenue_omu': [4760286.038, 15366.6728],
#   'type': {'Company': 2}},
#  {'id': 'qīng yú Corp Pier',
#   'country': 'Rio Isla',
#   'product_services': ['Textile products, apparels, and other industrial goods; Fibers and textiles, plastics and chemicals, IT-related products, carbon fiber composite materials, environment and engineering products, and life science products'],
#   'revenue_omu': [4662526.4033],
#   'type': {'Company': 1}},
#  {'id': 'Floyd Group',
#   'country': 'ZH',
#   'product_services': ['Consumer products'],
#   'revenue_omu': [4622176.2327],
#   'type': {'Company': 1}},
#  {'id': 'Acevedo-Hall',
#   'country': 'ZH',
#   'product_services': ['Snapchat; Spectacles'],
#   'revenue_omu': [4606513.6728],
#   'type': {'Company': 1}},
#  {'id': 'Italian Anchovy LC Delivery',
#   'country': 'Utoporiana',
#   'product_services': ['Machinery and complete systems for the filling and packaging industry and for the production of beverages'],
#   'revenue_omu': [4541755.8434],
#   'type': {'Company': 1}},
#  {'id': 'Krause Ltd',
#   'country': 'ZH',
#   'product_services': ['Fresh and cooked frozen shrimp, frozen cephalopod, canned seafood, canned pet food, and ready to eat products, as well as bakery products, including pies, rotis, sandwich tunas, and brownies; Animal feeds and agricultural products, and steel and aluminum food packaging products'],
#   'revenue_omu': [4532442.9126],
#   'type': {'Company': 1}},
#  {'id': 'Bihar   SRL Marine sanctuary',
#   'country': 'Puerto Sol',
#   'product_services': ['Retail sale of fashion clothing'],
#   'revenue_omu': [4485103.4116],
#   'type': {'Company': 1}},
#  {'id': 'Le LLC',
#   'country': 'ZH',
#   'product_services': ['Manufacturing, developing and marketing of products related to construction and building maintenance',
#    'Unknown'],
#   'revenue_omu': ['None', 4482714.9135],
#   'type': {'Company': 1, 'Beneficial Owner': 1}},
#  {'id': 'Assam  Market Incorporated -',
#   'country': 'Rio Isla',
#   'product_services': ['Soy sauce, soy sauce-based seasonings, foodstuffs, alcohol-based seasonings and alcoholic beverages, beverages, enzymes and other biochemical products; the wholesale of oriental food; and restaurant management services'],
#   'revenue_omu': [4248351.5442],
#   'type': {'Company': 1}},
#  {'id': 'Mandalore Kga Marine sanctuary',
#   'country': 'Utoporiana',
#   'product_services': ['Unknown'],
#   'revenue_omu': [4206613.8135],
#   'type': {'Company': 1}},
#  {'id': 'Mar de la Luna LLC',
#   'country': 'Rosvandor',
#   'product_services': ['Black copper and copper alloys', 'Unknown'],
#   'revenue_omu': [22966.6728, 4125934.0521],
#   'type': {'Company': 2}},
#  {'id': 'Ola del Este A/S',
#   'country': 'Kondanovia',
#   'product_services': ['General lines of merchandise'],
#   'revenue_omu': [4112563.5141],
#   'type': {'Company': 1}},
#  {'id': 'Ltd. Corporation Ltd. Corporation',
#   'country': 'Oceanus',
#   'product_services': ['Owns and operates United States-style membership shopping warehouse clubs under the trade name PriceSmart in Latin America and the Caribbean'],
#   'revenue_omu': [4070759.6728],
#   'type': {'Company': 1}},
#  {'id': 'Davis LLC',
#   'country': 'ZH',
#   'product_services': ['Glass products',
#    'Manufactures frozen fruits, frozen vegetables, and frozen fruit juices, ades, drinks, cocktail mixes and concentrates',
#    'Unknown'],
#   'revenue_omu': [13824.5785, 'None', 4057604.7097, 'Unknown'],
#   'type': {'Company': 3, 'Beneficial Owner': 6, 'Company Contacts': 6}},
#  {'id': 'West Bengal  S.A. de C.V.',
#   'country': 'Puerto del Mar',
#   'product_services': ['Oils, soaps, detergents, industrial greases, coffee, cosmetic products, personal hygiene and cleaning products, and related products and derivatives; Wheat and/or cereals, such as flour, noodles, cookies, and flour by-products; Industrial, commercial, and administrative advisory services; and ginning and marketing of cotton, oilseeds, and related by-products'],
#   'revenue_omu': [4056870.6115],
#   'type': {'Company': 1}},
#  {'id': 'Reef Rascals Plc Carriers',
#   'country': 'Oceanus',
#   'product_services': ['Copper tube and fittings; brass and copper alloy rod; bar and shapes; aluminum and brass forgings; aluminum and copper impact extrusions; plastic fittings and valves; refrigeration valves and fittings; and fabricated tubular products'],
#   'revenue_omu': [3987121.6728],
#   'type': {'Company': 1}},
#  {'id': 'Knight, Torres and Hall',
#   'country': 'ZH',
#   'product_services': ['Banking and financial products and services; Personal banking, business banking and online banking services, as well as other related financial and banking services; Loans, personal savings and mortgage services'],
#   'revenue_omu': [3912237.6728],
#   'type': {'Company': 1}},
#  {'id': 'Dutch Mussels Ltd. Liability Co',
#   'country': 'Azurionix',
#   'product_services': ['Offers chemical products for water-intensive industries; Provides bleaching and builder solutions for cleaners, laundry detergents, and automatic dishwashing products; and organic acids, salts, functional blends, and mixtures for the food, bakery, meat, beverage and dairy, and sugar and sweetener industries; Provides industrial raw water and waste water treatment solutions; additives to the mining industry; and coagulants and flocculants for the municipal water treatment, including drinking water and waste water treatment products'],
#   'revenue_omu': [3819893.0423],
#   'type': {'Company': 1}},
#  {'id': 'Lane, Rios and Hampton',
#   'country': 'ZH',
#   'product_services': ['Machinery and plant for the iron and steel industry'],
#   'revenue_omu': [3770085.5996],
#   'type': {'Company': 1}},
#  {'id': 'Ocean Emporium Wakame Ltd Services',
#   'country': 'Oceanus',
#   'product_services': ['Climate control products and systems consisting of heat exchangers, climate controls, compressors, and fluid transport systems; powertrain cooling systems; and interior products, including cockpit modules, instrument panels, door and console modules, and interior trim components'],
#   'revenue_omu': [3760666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Tamil Nadu s NV Merchants',
#   'country': 'Oceanus',
#   'product_services': ['Precision-engineered flow control equipment'],
#   'revenue_omu': [3619786.6728],
#   'type': {'Company': 1}},
#  {'id': 'Mar del Paraíso Ltd. Liability Co',
#   'country': 'Oceanus',
#   'product_services': ['A full line of groceries, and most have pharmacies, video rental outlets, in-store banking, and florist shops'],
#   'revenue_omu': [3591666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Náutica del Norte Oyj',
#   'country': 'Merigrad',
#   'product_services': ['Prepared feeds for farm animals; Farm supplies'],
#   'revenue_omu': [3503017.5551],
#   'type': {'Company': 1}},
#  {'id': 'Oceanic Oracle GmbH America',
#   'country': 'Coralmarica',
#   'product_services': ['Food products'],
#   'revenue_omu': [3488503.4346],
#   'type': {'Company': 1}},
#  {'id': 'Levine-Welch',
#   'country': 'ZH',
#   'product_services': ['Cleaning systems and equipment, known for its high-pressure cleaners'],
#   'revenue_omu': [3413330.103],
#   'type': {'Company': 1}},
#  {'id': 'La gan  Ltd. Liability Co',
#   'country': 'Kondanovia',
#   'product_services': ['Processed foods such as fermented food, starch products, and health food',
#    'Unknown'],
#   'revenue_omu': [3227337.0217, 'Unknown'],
#   'type': {'Company': 2}},
#  {'id': 'Playa del Mar Kga Family',
#   'country': 'Azurionix',
#   'product_services': ['Electrical machines and drives'],
#   'revenue_omu': [3206034.9693],
#   'type': {'Company': 1}},
#  {'id': 'Parker, Meyers and Smith',
#   'country': 'ZH',
#   'product_services': ['Food products'],
#   'revenue_omu': [3179587.7265],
#   'type': {'Company': 1}},
#  {'id': 'Lambert-Spence',
#   'country': 'ZH',
#   'product_services': ['Air transportation services for passengers and cargo'],
#   'revenue_omu': [3144666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Lindsey-Dunn',
#   'country': 'ZH',
#   'product_services': ['Cars, plants and equipment for railways and other rail and traffic systems as well as all related services'],
#   'revenue_omu': [3104427.0306],
#   'type': {'Company': 1}},
#  {'id': 'Walker-Chandler',
#   'country': 'ZH',
#   'product_services': ['Air brake components and systems and aluminum castings for original equipment manufacturers (OEMs)'],
#   'revenue_omu': [3057686.8372],
#   'type': {'Company': 1}},
#  {'id': 'Vespuci Ltd. Liability Co',
#   'country': 'Riodelsol',
#   'product_services': ['Plastic materials and synthetic resins'],
#   'revenue_omu': [3048431.1805],
#   'type': {'Company': 1}},
#  {'id': 'Zambezi Valley  Marine biology',
#   'country': 'Kondanovia',
#   'product_services': ['Textiles; industrial materials; special chemicals; heavy industry; construction; telecommunications; general trade'],
#   'revenue_omu': [3021277.8836],
#   'type': {'Company': 1}},
#  {'id': 'Hanson Group',
#   'country': 'ZH',
#   'product_services': ['Design, production and product management services',
#    'Unknown'],
#   'revenue_omu': ['None', 3011371.2813],
#   'type': {'Company': 1, 'Beneficial Owner': 1}},
#  {'id': 'Rogers, Kelly and Cobb',
#   'country': 'ZH',
#   'product_services': ['Cosmetics, perfumes and other related products'],
#   'revenue_omu': [2987951.8515],
#   'type': {'Company': 1}},
#  {'id': 'Náutica del Este NV',
#   'country': 'Utoporiana',
#   'product_services': ['Together with its subsidiaries (development, production, treatment, processing and marketing of special glasses, crystals, opto-mechanical and electronic devices)'],
#   'revenue_omu': [2976383.7534],
#   'type': {'Company': 1}},
#  {'id': 'Selous Game Reserve  Kga',
#   'country': 'Oceanus',
#   'product_services': ['Smelting and refining copper concentrates to obtain copper anodes and cathodes',
#    'Unknown'],
#   'revenue_omu': ['Unknown', 2866111.1284],
#   'type': {'Company': 2}},
#  {'id': 'Wright-Hopkins',
#   'country': 'ZH',
#   'product_services': ['Equipment that crushes, screens, grinds, processes, enriches, and recycles mineral products'],
#   'revenue_omu': [2807549.0915],
#   'type': {'Company': 1}},
#  {'id': 'Carter-Mayo',
#   'country': 'ZH',
#   'product_services': ['Inorganics, Chlor-alkali and PVC. Inorganics include animal feed and fertilizers for use in dry areas and for highly sensitive crops such as vegetables, fruit, flowers and tobacco; Fine Chemicals, Gelatin and Natural Derivatives which include organic chlorine derivatives that are used in industrial chemicals, pharmaceuticals and agrochemicals'],
#   'revenue_omu': [2764492.8487],
#   'type': {'Company': 1}},
#  {'id': 'Mar de la Aventura & Incorporated Shipping',
#   'country': 'Marebak',
#   'product_services': ['Design, production and distribution of LCD (liquid crystal display) monitors, computer monitors and flat television products'],
#   'revenue_omu': [2744518.7548],
#   'type': {'Company': 1}},
#  {'id': 'Black Group',
#   'country': 'ZH',
#   'product_services': ['Different varieties of paper for the printing and packaging industries',
#    'Unknown'],
#   'revenue_omu': ['None', 2671165.3935],
#   'type': {'Company': 1, 'Beneficial Owner': 1, 'Company Contacts': 1}},
#  {'id': 'Stewart, Mason and Mora',
#   'country': 'ZH',
#   'product_services': ['Integrated logistics solutions'],
#   'revenue_omu': [2652449.0606],
#   'type': {'Company': 1}},
#  {'id': 'Bahía Dorada Company Freight',
#   'country': 'Lumindoria',
#   'product_services': ['MANITOU (industrial and semi-industrial rough-terrain masted forklift-trucks); MANISCOPIC (high capacity rough-terrain and rotating, telescopic forklift-trucks); MANILOADER (compact loaders); MANITRANSIT (truck-mounted forklifts); MANIACCESS (vertical, articulated, scissor and telescopic access platforms); MANIHOE (forklift-trucks with front telescopic arm and a rear-mounted shovel); and MANILEC (warehouse equipment, including pallet forklift-trucks and stackers)'],
#   'revenue_omu': [2524906.872],
#   'type': {'Company': 1}},
#  {'id': 'Floyd LLC',
#   'country': 'ZH',
#   'product_services': ['Systems and components to natural and synthetic fiber industries for spinning, texturing, twisting, embroidery, and fabrication of nonwovens, as well as staple fiber plants, recycling machines, and machines used in rubber and plastic processing; Transmission systems for motor vehicles and industrial applications, which include gears, gear groups, planetary gear drives, custom gears, and custom gear assemblies; Gearboxes, angle drives, and transfer cases for cars and four-wheel drive vehicles; drive-lines for earth moving machines, forklift trucks, and city buses; transmissions and axles for luxury cars and special vehicles; and various components, including helical and spur gear kits, synchronizers, transmission kits, and sub-assemblies',
#    'Unknown'],
#   'revenue_omu': ['None', 2502844.0031],
#   'type': {'Company': 1, 'Beneficial Owner': 2, 'Company Contacts': 2}},
#  {'id': 'Lopez, Johnson and Deleon',
#   'country': 'ZH',
#   'product_services': ['Motor vehicles and other related activities'],
#   'revenue_omu': [2462299.254],
#   'type': {'Company': 1}},
#  {'id': 'Oceanic Oracle Ltd. Liability Co _',
#   'country': 'Utoporiana',
#   'product_services': ['Encoders, motor feed-back systems, positioning drives, ultrasonic sensors, magnetic cylinder sensors, photoelectric switches, contrast and luminescence scanners, distance sensors, and position finders; Develops designs, manufactures and distributes encoders, motor feedback systems and format adjustment drives'],
#   'revenue_omu': [2303505.5169],
#   'type': {'Company': 1}},
#  {'id': 'Richards and Sons',
#   'country': 'ZH',
#   'product_services': ['Power and high voltage, boxes and covers, cable ties and accessories, conduit and cable fittings, connectors - industrial power control, connectors - power and grounding, electrician supplies, hardware and closures, HVAC, lighting, metal framing and support systems, power distribution, power quality products and services, steel structures, terminals and lugs, connectors, markets and heatshrink, and wire management system',
#    'Unknown'],
#   'revenue_omu': [2302197.6728, 'Unknown'],
#   'type': {'Company': 2}},
#  {'id': 'Bush-Espinoza',
#   'country': 'ZH',
#   'product_services': ['Copper products'],
#   'revenue_omu': [2219345.2681],
#   'type': {'Company': 1}},
#  {'id': 'Line S.A. de C.V.',
#   'country': 'Lumindoria',
#   'product_services': ['International freight forwarding, transportation and logistics',
#    'Unknown'],
#   'revenue_omu': [2202396.4798, 5636.6728, 5366.6728],
#   'type': {'Company': 3}},
#  {'id': 'SilverFin Limited Liability Company',
#   'country': 'Oceanus',
#   'product_services': ['Grocery products'],
#   'revenue_omu': [2084666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Finest Dredge SRL Cargo',
#   'country': 'Oceanus',
#   'product_services': ['Softlines and Hardlines'],
#   'revenue_omu': [2083666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Hawkins-Benson',
#   'country': 'ZH',
#   'product_services': ['Exports salmon, whitefish, and pelagic fish'],
#   'revenue_omu': [2040574.8855],
#   'type': {'Company': 1}},
#  {'id': 'Hicks-Glass',
#   'country': 'ZH',
#   'product_services': ['Automotive parts and materials, IT and electronics, packaging materials, housing materials, daily necessities, beauty and health care products, coating materials, foodstuffs and medicine materials, and technologically advanced materials'],
#   'revenue_omu': [1995671.9282],
#   'type': {'Company': 1}},
#  {'id': 'Bailey, Mitchell and Cunningham',
#   'country': 'ZH',
#   'product_services': ['Coffee, dairy goods, confectionery, ice creams, Mediterranean salads, salty snacks and baked goods'],
#   'revenue_omu': [1958042.8006],
#   'type': {'Company': 1}},
#  {'id': 'Proctor, Valdez and Long',
#   'country': 'ZH',
#   'product_services': ['Die-casting products and aluminum dies; Offset printing machines and peripheral equipment, among others; Electric power tools, lawn and garden equipment, door closers, hinges and architectural hardware, among others'],
#   'revenue_omu': [1885714.4874],
#   'type': {'Company': 1}},
#  {'id': 'Baltic Catch Co Merchants',
#   'country': 'Oceanus',
#   'product_services': ['Sound solutions'],
#   'revenue_omu': [1804666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Surfside  Limited Liability Company Marine ecology',
#   'country': 'Riodelsol',
#   'product_services': ['Caterpillar equipment that include construction, mining, energy, oil and maritime, and materials handling'],
#   'revenue_omu': [1804200.5845],
#   'type': {'Company': 1}},
#  {'id': 'Arena del Sol SE',
#   'country': 'Puerto Sol',
#   'product_services': ['Intimates, sneakers, jeans, shoes, bags, timeframes, jewellery, shades, and accessories, as well as furniture, helmets, fragrances, as well as lighting products, and other related products'],
#   'revenue_omu': [1763481.6591],
#   'type': {'Company': 1}},
#  {'id': 'Wave Warriors S.A. de C.V. Express',
#   'country': 'Lumindoria',
#   'product_services': ['Beer, ale, and malt liquors, as well as nonalcoholic beer and other related products'],
#   'revenue_omu': [1761580.7537],
#   'type': {'Company': 1}},
#  {'id': 'Playa del Tesoro Co',
#   'country': 'Alverossia',
#   'product_services': ['Provides steel castings and forgings for power generation, steel-making, chemical machinery, nuclear power-related machinery and equipment, and die material industries; pressure vessels, clad steel plates and pipes, and steel plates for oil refining, petrochemical, general chemical, and power generation industries; and wind turbine system equipment'],
#   'revenue_omu': [1751317.0946],
#   'type': {'Company': 1}},
#  {'id': 'Balkan Trout Ltd. Liability Co',
#   'country': 'Rio Isla',
#   'product_services': ['Total services for the merchandising of processed food, including consulting, market research, product development, package design, import/export, OEM manufacturing, and the contract packaging of dry and liquid food products',
#    'Control cables and peripheral equipment'],
#   'revenue_omu': [284697.9765, 1729005.5858],
#   'type': {'Company': 2}},
#  {'id': 'Lake Motoso  Sea spray',
#   'country': 'Marebak',
#   'product_services': ['Chemical and other related products'],
#   'revenue_omu': [1683603.6829],
#   'type': {'Company': 1}},
#  {'id': 'Anderson Group',
#   'country': 'ZH',
#   'product_services': ['Electric arc furnaces ( EAF), ladle refining furnaces (LF), continuous casting machines (CCM), rolling mills and melt shop auxiliary systems',
#    'Unknown',
#    'Food and non-food products'],
#   'revenue_omu': ['None', 9347.4958, 1652887.8713],
#   'type': {'Company': 2, 'Beneficial Owner': 6, 'Company Contacts': 6}},
#  {'id': 'AquaDelicious S.A. de C.V. Overseas',
#   'country': 'Utoporiana',
#   'product_services': ['Agricultural seeds'],
#   'revenue_omu': [1635565.6859],
#   'type': {'Company': 1}},
#  {'id': 'Olas del Sur Ltd',
#   'country': 'Faraluna',
#   'product_services': ['Electric home appliances and different types of electric devices and utilities for the final user'],
#   'revenue_omu': [1623759.8077],
#   'type': {'Company': 1}},
#  {'id': 'Sloan-Hall',
#   'country': 'ZH',
#   'product_services': ['Covers six product divisions: Synthetic resins division, unsaturated polyester resins division, copper-clad laminates division, photoresist materials division and optical materials division'],
#   'revenue_omu': [1608728.8389],
#   'type': {'Company': 1}},
#  {'id': 'Barents Sea  GmbH Cargo',
#   'country': 'Marebak',
#   'product_services': ['Electrical household appliances'],
#   'revenue_omu': [1586678.7367],
#   'type': {'Company': 1}},
#  {'id': 'Sea Star LLC Shipping',
#   'country': 'Zawalinda',
#   'product_services': ['Operation of fish hatcheries and preserves'],
#   'revenue_omu': [1507513.6728],
#   'type': {'Company': 1}},
#  {'id': 'Playa de la Luna A/S',
#   'country': 'Utoporiana',
#   'product_services': ['Offers frits, porcelain and other glass enamels, glazes, stains, decorating colors, pigments, inks, polishing materials, dielectrics, electronic glasses, and other specialty coatings'],
#   'revenue_omu': [1475769.6109],
#   'type': {'Company': 1}},
#  {'id': 'zhāng yú Ges.m.b.H. Solutions',
#   'country': 'Coral Solis',
#   'product_services': ['Electronic products for home and office use'],
#   'revenue_omu': [1471665.3948],
#   'type': {'Company': 1}},
#  {'id': 'Miller Ltd',
#   'country': 'ZH',
#   'product_services': ['Pharmaceutical preparations', 'Unknown'],
#   'revenue_omu': ['None', 1436482.9925, 4806.2698],
#   'type': {'Company': 2, 'Beneficial Owner': 5, 'Company Contacts': 1}},
#  {'id': 'Diao yu bi sai  Sp Delivery',
#   'country': 'Utoporiana',
#   'product_services': ['Custom-made envelopes in aluminum and steel'],
#   'revenue_omu': [1428129.2933],
#   'type': {'Company': 1}},
#  {'id': 'Green Valley Marine biology Kelp',
#   'country': 'Oceanus',
#   'product_services': ['Casual apparel, footwear and accessories for fashion-conscious young men and women'],
#   'revenue_omu': [1349853.6728],
#   'type': {'Company': 1}},
#  {'id': 'ReefRider Ges.m.b.H. Marine life',
#   'country': 'Rio Isla',
#   'product_services': ['Automobile-related components, such as piston rings, cylinder liners, valve seats, metal gaskets and aluminum products; Internal combustion-related parts, automatic temperature control valves, infrared equipment, copper alloys, tools'],
#   'revenue_omu': [1340753.3468],
#   'type': {'Company': 1}},
#  {'id': 'Playa del Mar SE Transit',
#   'country': 'Oceanus',
#   'product_services': ['Medical and orthopaedic goods and hospital equipment and supplies'],
#   'revenue_omu': [1326666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Olas del Sur Ltd. Corporation',
#   'country': 'Vesperanda',
#   'product_services': ['Adhesives and industrial chemicals'],
#   'revenue_omu': [1311044.3353],
#   'type': {'Company': 1}},
#  {'id': 'Hensley-Martinez',
#   'country': 'ZH',
#   'product_services': ['Development of real estate properties, administration of project contracting business; Ocean freight transportation, and operation of deep sea fishing'],
#   'revenue_omu': [1288524.2039],
#   'type': {'Company': 1}},
#  {'id': 'Brown-Ortiz',
#   'country': 'ZH',
#   'product_services': ['Laundry detergent and dishwashing liquid, shampoo, toothpaste, hair colorants and shower gel, and adhesives as well as sealants and surface treatment for consumer and industrial applications'],
#   'revenue_omu': [1288058.3071],
#   'type': {'Company': 1}},
#  {'id': 'Atkins, Walters and Hill',
#   'country': 'ZH',
#   'product_services': ['Pharmaceutical and ancillary products'],
#   'revenue_omu': [1282006.6025],
#   'type': {'Company': 1}},
#  {'id': 'Fernandez, Griffin and Gill',
#   'country': 'ZH',
#   'product_services': ['Food; household supplies; clothes; consumer electronics; toys'],
#   'revenue_omu': [1279927.8223],
#   'type': {'Company': 1}},
#  {'id': 'Jammu & Kashmir Sea  Sagl Merchants',
#   'country': 'Puerto Sol',
#   'product_services': ['Land operations, air and sea freight as well as comprehensive logistics solutions and global supply chain management from a single source; Local trucking and courier services, and freight transport by road services, as well as air freight; Arranging transportation of freight between shippers and carriers'],
#   'revenue_omu': [1275143.2191],
#   'type': {'Company': 1}},
#  {'id': 'Russian River Corporation Cargo',
#   'country': 'Oceanus',
#   'product_services': ['Offers tunics, tops, sweaters, T-shirts, skirts and dresses, pants and shorts, jackets, outerwear, shoes, handbags, shoes, accessories, jewelry, and furnishings, as well as apparel for kids'],
#   'revenue_omu': [1274666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Surf and Sand Tilapia',
#   'country': 'Utoporiana',
#   'product_services': ['Complete aluminium and steel systems, and solar products'],
#   'revenue_omu': [1267853.9834],
#   'type': {'Company': 1}},
#  {'id': 'Rybachit Ltd. Corporation Transportation',
#   'country': 'Utoporiana',
#   'product_services': ['Adhesive tapes; correction and adhesive rollers; glues and glue sticks; hook and loop tapes; self adhesive hooks; Auto protection; decorating; desk and office; household helpers; insect protection; mounting and hanging; and renovating and repairing; and saving energy'],
#   'revenue_omu': [1265463.7439],
#   'type': {'Company': 1}},
#  {'id': 'Coral Rojo GmbH Line',
#   'country': 'Rio Isla',
#   'product_services': ['Chemical products'],
#   'revenue_omu': [1217067.6923],
#   'type': {'Company': 1}},
#  {'id': 'Mar de la Vida AG',
#   'country': 'Rio Isla',
#   'product_services': ['Fish and meat products'],
#   'revenue_omu': [1205867.7185],
#   'type': {'Company': 1}},
#  {'id': 'Smith, Silva and Rodriguez',
#   'country': 'ZH',
#   'product_services': ["Garments, textiles and accessories (manicure kit, hair straightener, ladies' zipper jackets, and ladies' blazers)"],
#   'revenue_omu': [1202295.83],
#   'type': {'Company': 1}},
#  {'id': 'Vance-Cunningham',
#   'country': 'ZH',
#   'product_services': ['Apple, garlic flavored, white Balsamic, sherry, tarragon, raspberry, rosemary, red wine, and Balsamic from Modena'],
#   'revenue_omu': [1201489.0579],
#   'type': {'Company': 1}},
#  {'id': 'Elara Mussel AS Marine biology',
#   'country': 'Icarnia',
#   'product_services': ['Import, export, and offshore trade; Project management; Finished products; Business investment services'],
#   'revenue_omu': [1184139.9954],
#   'type': {'Company': 1}},
#  {'id': 'Hernandez and Sons',
#   'country': 'ZH',
#   'product_services': ['Technology, Leadership, Innovation, Careers, Our Brands, Securing Sustainable Growth, Kerry Group is a leader in global food ingredients, bringing technology leadership and sustainable growth to the food and beverage industries, Grow your career: our brands are produced using cutting edge advanced food technology innovation source: freelance researcher',
#    'Food products',
#    'Footwear',
#    'Unknown'],
# ...
#   'revenue_omu': [90455.99],
#   'type': {'Company': 1}},
#  {'id': 'Congo Rapids   Ltd. Corporation',
#   'country': 'Brindivaria',
#   'product_services': ['HON Atlantic Salmon; HG Atlantic Salmon; Fresh Atlantic Fillet; Frozen Trim D IQF Atlantic Fillet; Trim D IVP Atlantic Frozen Fillet; HG Coho Salmon; and vacuum portions of Atlantic salmon with/without skin',
#    "Children's accessories, desk accessories, dry erase cleaners, and dry erase erasers; art pencils and accessories; art drawing products; and erasers, highlighters, liquid paper corrections, markers and transparency markers, pencils, refills, pens, presentation products, sets, and kits"],
#   'revenue_omu': [90386.2119, 33526.7005],
#   'type': {'Company': 2}},
#  {'id': 'The Salty Pearl GmbH',
#   'country': 'Oceanus',
#   'product_services': ['Agricultural produce'],
#   'revenue_omu': [90266.6728],
#   'type': {'Company': 1}},
#  {'id': 'Haikou Ferry Co Marine',
#   'country': 'Jiraputra',
#   'product_services': ['Frozen fruit and vegetable products'],
#   'revenue_omu': [90227.7602],
#   'type': {'Company': 1}},
#  {'id': 'Neva  S.A. de C.V. Shipping',
#   'country': 'Oceanus',
#   'product_services': ['Seafood products'],
#   'revenue_omu': [90066.6728],
#   'type': {'Company': 1}},
#  {'id': 'Mar de Plata Ltd. Liability Co',
#   'country': 'Nalakond',
#   'product_services': ['Coffee'],
#   'revenue_omu': [90054.8896],
#   'type': {'Company': 1}},
#  {'id': 'Benson Ltd',
#   'country': 'ZH',
#   'product_services': ['Fashion apparel, clothing and accessories'],
#   'revenue_omu': [89966.6728],
#   'type': {'Company': 1}},
#  {'id': 'Viento Azul Incorporated Forwading',
#   'country': 'Oceanus',
#   'product_services': ['Suite of online retail stores that serve a diverse set of consumers from the cargo control industry to eco-friendly builders/renovators'],
#   'revenue_omu': [89866.6728],
#   'type': {'Company': 1}},
#  {'id': 'Kong zhong diao yu  Kga',
#   'country': 'Puerto Sol',
#   'product_services': ['Knit and woven fabrics, interior fabrics, bedding, clothing, highly-functional textiles, dust-proof/flame-retardant fibers, non-woven fabrics and industrial special fabrics, PET films (polyethylene terephthalate), PC resins, and other chemical products',
#    'Fishery products'],
#   'revenue_omu': [14626.6728, 89783.1399],
#   'type': {'Company': 2}},
#  {'id': 'Olas del Sur AS Industrial',
#   'country': 'Nalakond',
#   'product_services': ['Footwear and accessories'],
#   'revenue_omu': [89744.8167],
#   'type': {'Company': 1}},
#  {'id': 'Ob River Surfboard AG Marine conservation',
#   'country': 'Kondanovia',
#   'product_services': ['Fish and seafood products'],
#   'revenue_omu': [89603.5322],
#   'type': {'Company': 1}},
#  {'id': 'Wilson, Rivas and Simpson',
#   'country': 'ZH',
#   'product_services': ['Trade agents and brokers'],
#   'revenue_omu': [89570.9508],
#   'type': {'Company': 1}},
#  {'id': '9 Shark S.A. de C.V. Brothers',
#   'country': 'Kondanovia',
#   'product_services': ['Pat-ang-geum (processed red bean paste), Yo-kan (red bean sweet jelly), Pat-juk (red bean sweet porridge), Pat for Bing-su (processed red bean paste for shaved ice bowls), A-dzu-ki (red bean with rice flour)'],
#   'revenue_omu': [89559.5005],
#   'type': {'Company': 1}},
#  {'id': 'Burton, Hernandez and Robertson',
#   'country': 'ZH',
#   'product_services': ['Seafood'],
#   'revenue_omu': [89465.3252],
#   'type': {'Company': 1}},
#  {'id': 'Solutions Ltd. Liability Co',
#   'country': 'Oceanus',
#   'product_services': ['Motor vehicle parts and accessories'],
#   'revenue_omu': [89366.6728],
#   'type': {'Company': 1}},
#  {'id': 'Náutica del Norte Ltd',
#   'country': 'Oceanus',
#   'product_services': ['In-line and custom textiles for hotels, casinos, cruise ships, and restaurants'],
#   'revenue_omu': [89366.6728],
#   'type': {'Company': 1}},
#  {'id': 'Icelandic Cat Company Freight',
#   'country': 'Marifada',
#   'product_services': ['In-flight meals and aircraft interior cleaning'],
#   'revenue_omu': [89366.67],
#   'type': {'Company': 1}},
#  {'id': 'Smith-Campbell',
#   'country': 'ZH',
#   'product_services': ['Gelatines and other related chemical products',
#    'Unknown'],
#   'revenue_omu': ['None', 89269.8748],
#   'type': {'Company': 1, 'Beneficial Owner': 1}},
#  {'id': 'Náutica del Este Ltd. Corporation',
#   'country': 'Oceanus',
#   'product_services': ['Stationery and office supplies'],
#   'revenue_omu': [88966.6728],
#   'type': {'Company': 1}},
#  {'id': 'Selous Game Reserve  S.A. de C.V.',
#   'country': 'Isliandor',
#   'product_services': ['Body composition analyzers, blood pressure monitors, blood glucose monitors, digital thermometers, and nasal care devices'],
#   'revenue_omu': [88748.5759],
#   'type': {'Company': 1}},
#  {'id': 'suō yú Line Manatee',
#   'country': 'Mawazam',
#   'product_services': ['Frozen seafood and a wide array of processed value-added products'],
#   'revenue_omu': [88372.2789],
#   'type': {'Company': 1}},
#  {'id': 'SeaFusion Barge LC Enterprises',
#   'country': 'Oceanus',
#   'product_services': ['Production and distribution of toy and stationery products in the United States'],
#   'revenue_omu': [88366.6728],
#   'type': {'Company': 1}},
#  {'id': "Seafarer's Club Plc and Son's",
#   'country': 'Kondanovia',
#   'product_services': ['Wire to board crimp style, wire to board insulation displacement, board to board, card edge, ribbon cable, headers/jumpers/compression type, card, coaxial or optical fiber, interface connection, wire to wire, and automotive connectors, as well as chain terminals/splices, solderless terminals and splices, shunt wires, application tools/machines, connector kits, and protectors'],
#   'revenue_omu': [88328.4563],
#   'type': {'Company': 1}},
#  {'id': 'Fitzgerald-Kelley',
#   'country': 'ZH',
#   'product_services': ['Preparation and processing of textile fibers and other related products'],
#   'revenue_omu': [88066.6728],
#   'type': {'Company': 1}},
#  {'id': 'Mbowo ship SE Forwading',
#   'country': 'Mawalara',
#   'product_services': ['Floor & wall tiles, sanitary ware, glazed porcelain tiles, porcelain tiles'],
#   'revenue_omu': [87987.3548],
#   'type': {'Company': 1}},
#  {'id': 'Barnett Ltd',
#   'country': 'ZH',
#   'product_services': ['Semiconductor and other electronic component',
#    'Unknown'],
#   'revenue_omu': ['None', 87957.9215],
#   'type': {'Company': 1, 'Beneficial Owner': 3}},
#  {'id': 'Náutica del Sol Sagl Solutions',
#   'country': 'Oceanus',
#   'product_services': ['Standby power supplies'],
#   'revenue_omu': [87866.6728],
#   'type': {'Company': 1}},
#  {'id': 'Jammu & Kashmir Sea  Dashi',
#   'country': 'Oceanus',
#   'product_services': ['A chemical science firm with a focus on the development of high purity, high performance products and services'],
#   'revenue_omu': [87766.6728],
#   'type': {'Company': 1}},
#  {'id': 'Surf and Sea Ltd. Liability Co Logistics',
#   'country': 'Rio Isla',
#   'product_services': ['Pharmaceutical raw materials ( binders, fillers, disintegrants, sweeteners, and other traditional excipients); Functional excipients for new development areas (ODT and SEDDS; and viable solutions for diverse applications); Machinery ( small-amount samplers, material handling systems, and precision capsule fillers for pharmaceutical and chemical producers); Analytical and testing equipment (dissolution apparatus, tap density testers, and taste sensing systems ); Additives for engine oils and industrial lubricants; Test equipment for lubricating oil; Petrochemical products for use in (paint, ink, adhesive, textile processing, paper manufacturing, and cosmetics); Food ingredients and additives for (fermentation media and seasoning, confectionery, and bakery applications); Japanese made biochemical products (enzymes, food additives, and chemicals); LED; Halogen lamos; Ultra violet lamps; Specialty lamps'],
#   'revenue_omu': [87639.2427],
#   'type': {'Company': 1}},
#  {'id': 'Mar y Luna GmbH',
#   'country': 'Marebak',
#   'product_services': ['Manufacturing and exporting laundry, non-woven/PVC storage items, cooler bag and shopping bag with one stop sourcing service'],
#   'revenue_omu': [87538.4103],
#   'type': {'Company': 1}},
#  {'id': 'Matthew Oyj Marine sanctuary',
#   'country': 'Marebak',
#   'product_services': ['Processing and selling frozen and breaded products'],
#   'revenue_omu': [87460.5918],
#   'type': {'Company': 1}},
#  {'id': 'qīng yú GmbH & Co. KG',
#   'country': 'Oceanus',
#   'product_services': ['Release coatings, engineering elastomers, healthcare products, specialty fluids, emulsions and resins'],
#   'revenue_omu': [87366.6728],
#   'type': {'Company': 1}},
#  {'id': 'Ross, Hardy and Richardson',
#   'country': 'ZH',
#   'product_services': ['Freight transport services'],
#   'revenue_omu': [87073.2092],
#   'type': {'Company': 1}},
#  {'id': 'Greek ermen SE Solutions',
#   'country': 'Utoporiana',
#   'product_services': ['Customized blow-molding & parts and assemblies'],
#   'revenue_omu': [86970.7719],
#   'type': {'Company': 1}},
#  {'id': 'Sparks Group',
#   'country': 'ZH',
#   'product_services': ['Seafood and related products', 'Unknown'],
#   'revenue_omu': ['None', 86485.008],
#   'type': {'Company': 1, 'Company Contacts': 1}},
#  {'id': 'Yenisei  Eel GmbH & Co. KG Services',
#   'country': 'Thessalandia',
#   'product_services': ['Canned and cured fish and seafoods', 'Unknown'],
#   'revenue_omu': [10707.2542, 86380.956, 8543.8212],
#   'type': {'Company': 3}},
#  {'id': 'Mcdonald LLC',
#   'country': 'ZH',
#   'product_services': ['Wholesale distribution of piece goods, fabrics, knitting yarns, thread and other notions, and hair accessories',
#    'Unknown'],
#   'revenue_omu': ['None', 86258.0193],
#   'type': {'Company': 1, 'Company Contacts': 1}},
#  {'id': 'Grant-Williams',
#   'country': 'ZH',
#   'product_services': ['Adhesive and sealant products', "Children's shoes"],
#   'revenue_omu': [30571.4835, 86244.1795],
#   'type': {'Company': 2}},
#  {'id': 'Halie Seafoam N.V. Transit',
#   'country': 'Nalakond',
#   'product_services': ['Processed fish products'],
#   'revenue_omu': [86043.459],
#   'type': {'Company': 1}},
#  {'id': 'Vleikurper S.A. de C.V.',
#   'country': 'Oceanus',
#   'product_services': ['High volume shipper with a special focus on export volumes to Asia, Europe, Mediterranean, Middle East and South America'],
#   'revenue_omu': [85866.6728],
#   'type': {'Company': 1}},
#  {'id': 'Coral del Cielo Plc',
#   'country': 'Oceanus',
#   'product_services': ['Frozen seafood products'],
#   'revenue_omu': [85666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Liu-Dominguez',
#   'country': 'ZH',
#   'product_services': ['Aircraft parts and auxiliary equipment'],
#   'revenue_omu': [85584.1238],
#   'type': {'Company': 1}},
#  {'id': 'Southeast Ltd. Liability Co',
#   'country': 'Oceanus',
#   'product_services': ['Provision of freight trucking and other related transportation services',
#    'Railway track & accessories, such as fish plates, base plates, elastic fasting, rubber/rail pads, metal & nylon liners, rail anchor, bolt & nut, and glued insulated rail joint; turnout systems, such as switch, crossing, and switch expansion joint; rolled section; railway sleepers; and light rail'],
#   'revenue_omu': [28661.0485, 85566.6728],
#   'type': {'Company': 2}},
#  {'id': 'Jammu & Kashmir  Ges.m.b.H. Solutions',
#   'country': 'Arreciviento',
#   'product_services': ['Offers shrimps of the highest quality to the international market and fulfill any type of processing request from its valued customers'],
#   'revenue_omu': [85098.6488],
#   'type': {'Company': 1}},
#  {'id': 'Mcdonald and Sons',
#   'country': 'ZH',
#   'product_services': ['Leather, leatherworking tools, buckles and adornments for belts, leather dyes and finishes, saddle and tack hardware, and do-it-yourself kits which also manufactures leather lacing and kits; Tools, leather, accessories, kits and teaching materials',
#    'Unknown'],
#   'revenue_omu': ['None', 85001.6728],
#   'type': {'Company': 1, 'Beneficial Owner': 4}},
#  {'id': 'Aguamarina S.A. de C.V.',
#   'country': 'Marebak',
#   'product_services': ['Measuring, compounding, extruding, and pelletizing equipment'],
#   'revenue_omu': [84857.8698],
#   'type': {'Company': 1}},
#  {'id': 'Ramirez, Ward and Adams',
#   'country': 'ZH',
#   'product_services': ['Involved in the following activities: canning seafood (including soup); smoking, salting, and drying seafoods; eviscerating fresh fish by removing heads, fins, scales, bones, and entrails; shucking and packing fresh shellfish; processing marine fats and oils; and freezing seafood'],
#   'revenue_omu': [84815.0126],
#   'type': {'Company': 1}},
#  {'id': 'Tiao piao  Ltd. Corporation',
#   'country': 'Oceanus',
#   'product_services': ['Project logistics and consulting, worldwide container services, break bulk cargo shipment, chartering, crosstrades, multimodal transport solutions, storage, cargo handling, crating and transport insurance'],
#   'revenue_omu': [84766.6728],
#   'type': {'Company': 1}},
#  {'id': 'Baker, Raymond and Rivas',
#   'country': 'ZH',
#   'product_services': ['High pressure processing equipment for the aerospace industry'],
#   'revenue_omu': [84737.8162],
#   'type': {'Company': 1}},
#  {'id': 'Kelly, Simmons and Davis',
#   'country': 'ZH',
#   'product_services': ['Electrical materials and systems solutions'],
#   'revenue_omu': [84666.677],
#   'type': {'Company': 1}},
#  {'id': 'Surf and Sand Company Family',
#   'country': 'Oceanus',
#   'product_services': ["Fresh and frozen lamb, and related protein products (mixed cut packs, short cut and boneless legs, short loin saddles, rack chine offs, mild and hot lamb sausages, shoulders, chilled atmosphere packaging technology carcasses, whole carcasses, lamb shanks, ground lambs, shepherd's pies, lamb burgers, seasoned medallions, and diced products; and venison, such as Denver legs, boneless short loins, French racks, tenderloins, strip loins, and saddles)"],
#   'revenue_omu': [84666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Henties Bay  A/S Logistics',
#   'country': 'Oceanus',
#   'product_services': ['Unknown'],
#   'revenue_omu': [84666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Lake Manyara   SE Line',
#   'country': 'Oceanus',
#   'product_services': ['Range of furniture, home decor and gifts'],
#   'revenue_omu': [84266.6728],
#   'type': {'Company': 1}},
#  {'id': 'Yu lou  ОАО Worldwide',
#   'country': 'Mawazam',
#   'product_services': ['Specialized grade rubber, such as synthetic rubber'],
#   'revenue_omu': [84072.7448],
#   'type': {'Company': 1}},
#  {'id': 'Kafue River  Limited Liability Company Salmon',
#   'country': 'Puerto Sol',
#   'product_services': ['Credit intermediation and related activities'],
#   'revenue_omu': [83839.9577],
#   'type': {'Company': 1}},
#  {'id': 'La gan  OJSC Solutions',
#   'country': 'Puerto Sol',
#   'product_services': ['Packaging machines and systems'],
#   'revenue_omu': [83753.024],
#   'type': {'Company': 1}},
#  {'id': 'Telangana  S.A. de C.V.',
#   'country': 'Nalakond',
#   'product_services': ['Motor vehicle parts and accessories',
#    'Frozen-at-sea fish products'],
#   'revenue_omu': [20866.6728, 83707.7982],
#   'type': {'Company': 2}},
#  {'id': 'King-Franklin',
#   'country': 'ZH',
#   'product_services': ["Skin lotions, emulsions, creams, cleansings, essences, body products, children's cosmetics, and others; makeup products comprise makeup bases, foundations, concealers, two-way cakes, face powders, eye shadow products, mascaras, eye liners, lipsticks, primers, and BB creams; and oriental herb cosmetics consist of skin lotions, serums, and creams; Liquid perfumes, home fragrances, and other fragrant products; mask sheets comprise sheet masks, hydrogels, and local patches; and nail products consist of oily, UV gel, and water nails"],
#   'revenue_omu': [83666.6728],
#   'type': {'Company': 1}},
#  {'id': 'Rufiji Delta  ОАО Shoal',
#   'country': 'Coralada',
#   'product_services': ['Consultancy about CO2 technology; production, installation, start-up and commissioning of CO2 plants; service contracts; trouble shooting; and components and spare parts'],
#   'revenue_omu': [83521.0309],
#   'type': {'Company': 1}},
#  ...]

# %% [markdown]
# #### Add Unknown Nodes

# %%
# Add unknown nodes
df_unknown_src = df_links[~df_links['source'].isin(df_nodes['id'])]
unknown_src_list = list(set(df_unknown_src['source']))
target_list = list(set(df_links['target']))
unknown_nodes = [
    {
        "id": node,
        "country": "Unknown",
        "product_services": ["Unknown"],
        "revenue_omu": ["Unknown"],
        "type": {"Unknown":1}
    }
    for node in unknown_src_list
] + [
    {
        "id": node,
        "country": "Unknown",
        "product_services": ["Unknown"],
        "revenue_omu": ["Unknown"],
        "type" : dict(Counter(df_links[df_links['target'] == node]['type']))
    }
    for node in target_list
]
unknown_nodes
# Out:
# [{'id': 'Bradford, Franklin and Mcmahon',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Graham, Ward and Schmidt',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones, Owens and Sullivan',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gonzalez-Adams',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Martin-Ayala',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Dominguez, Willis and White',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Bryan-Odonnell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rangel Inc',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Good, Knox and Chandler',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Schmidt, Richmond and Bell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Banks, Cruz and Norton',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gray, Osborne and Hubbard',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wilson, Madden and Taylor',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Oliver-Williams',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Potts-Haynes',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Love-Perry',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hanna, Rogers and Moore',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith, Robinson and Ochoa',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Holt, Griffin and Blake',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mitchell-Downs',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Butler-Lyons',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ramsey-Perez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Berg, Buckley and Cox',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ochoa LLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Guinea Gulf  LC Forwading',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Perez-Duffy',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Fry, Pope and Edwards',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Stanton LLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Reed, Powell and Greer',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Harper-Ferguson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Seashell Seekers S.A. de C.V.',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Townsend, Durham and Brown',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Meadows, Malone and Willis',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Odonnell Inc',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Kramer-Nicholson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Estrada PLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hahn-Jones',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Simon-Nguyen',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Kelly-Livingston',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Kelly, Harris and Stone',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Harris, Estes and Cruz',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Blackwell-Ross',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Morton-Merritt',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Farmer, Roberts and Smith',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rodriguez-Hernandez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Lang, Gonzales and Bond',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hall, Bautista and Chapman',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Brown, Anderson and Henderson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Lindsey-Nelson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gomez-Powell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wagner, Ferrell and Orozco',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Knight-Werner',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Craig-Levine',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Cervantes, Flores and Valdez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Fischer-Edwards',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Franco Ltd',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Reyes, Armstrong and Rodriguez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Proctor-Harris',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hicks, Gibson and Cameron',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Cortez-Johnson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Brown-Brown',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Lake Victoria Catch  Ltd. Liability Co',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Reyes-Robertson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Walters-Velasquez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mccoy-Brown',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Orr-Carr',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Kim, Fisher and Perkins',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Thompson-Sanchez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Harrington-Smith',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rowland, Ross and Mitchell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Kelly-Garner',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Sawyer, Shelton and Barton',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wagner, Smith and Smith',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Austin, Brown and Sutton',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Peters-King',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Miller-Stone',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Thompson-Murray',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Tucker, Miller and Hill',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Meza-Knight',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Russell, Cole and Murray',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Alvarado Group',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Patel, Cochran and Powell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gomez-Johnson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Nelson, Massey and Dennis',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Lucas, White and Whitney',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Miller-Munoz',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ramirez, Flores and Monroe',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Romero Ltd. Corporation Solutions',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Morris, Henderson and Rogers',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Morris-Escobar',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Fletcher, Estes and Kelley',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Arias-Carey',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Foster, Savage and Santiago',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Torres-Weber',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Kelly-Haney',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hughes-Hernandez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Fowler, Lawrence and Howard',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Collins-Lynch',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mann Ltd',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Bradshaw, Riley and Rhodes',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mitchell, Torres and Carpenter',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Atkins, Anderson and Owen',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mills-Henderson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wilson-Obrien',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Goodwin, Reed and Smith',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ingram, Johnson and Mcpherson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Montgomery, Peterson and Gardner',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Robles-Norton',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Page-Johnston',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Graham-Clark',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith-Gray',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Crawford, Phillips and Gross',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wilson, Collins and Thomas',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Sparks, Williams and Watson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Sweeney-Fox',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Johnson-Andersen',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Reilly-Bond',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones, Levy and Bauer',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rodriguez, Medina and Williams',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Williams, Grant and Maldonado',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith-Joseph',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hancock, Chandler and Stevens',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Watts-Bush',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hernandez-Elliott',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Dunn-Rivera',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Phelps-Bird',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Arias, Huang and Gilbert',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Phillips-Murphy',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rogers, Garcia and Ballard',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Cook, Butler and Barnett',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Payne, White and Rowland',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Potter Group',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mcbride, Wagner and Greene',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Holder-Weber',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Robinson-Fernandez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Clay, Norris and Rodriguez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Clark, Bailey and Hansen',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Bowman, Serrano and Edwards',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Thomas-Reeves',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Monroe Group',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'George, Reed and Tucker',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Cochran-Wiggins',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Cruz, Joseph and Meyer',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Davis, Horton and Lewis',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones, Burke and Barber',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Adams-Howell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Zambezi Gorge  Salmon LLC United',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Garcia-Porter',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Carlson, Brooks and Roth',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Frey, Mitchell and Webb',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Bradford-Glover',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Bartlett Inc',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Cruz, Stephenson and Hughes',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Murphy, Miller and Cruz',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hardy, Michael and Harris',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Morris, Smith and Fox',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Barker, Santos and Gill',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Murphy, Cummings and Mendoza',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Reeves, Beck and Glenn',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Shields-Welch',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Cunningham-Alvarez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith, Walker and Cook',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mitchell-Vargas',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hartman-Jones',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mcclain, Kemp and Simpson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gibson, Johnson and Carney',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Eaton, Hicks and Medina',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Kennedy, Taylor and Williams',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Henry-Weber',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Bradshaw-Mcbride',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Camacho, Richardson and Myers',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mcclain-Butler',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Bowers-Odonnell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Potts-Richardson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Scott, Kelley and Reyes',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hays-Vasquez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rodriguez-Parks',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Norman and Sons',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Bailey-Lewis',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'White, Taylor and Frazier',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Carter, Neal and Crawford',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Torres, Levine and Wyatt',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Shaw, Young and Jones',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Davis-Murray',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jenkins-Cantu',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Douglas-Estrada',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Flynn and Sons',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'West-Chavez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mueller and Sons',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Larsen Ltd',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Davis, Wang and Douglas',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wilson-Sweeney',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Goodman, Berry and Butler',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Blevins and Sons',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Obrien-Herman',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Vasquez, Clark and Lambert',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Whale Swordfish Inc Marine',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Lucas, Hickman and Gardner',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'White, Schroeder and King',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Thomas, Molina and Bennett',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Davis, Walker and Davis',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Krause, Lindsey and Goodman',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Murphy, Norman and Joyce',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Olas del Mar OJSC and',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Murray-Chapman',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones-Cisneros',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Roy-Mercer',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Perez, Schneider and Morris',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ortiz-Hernandez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jordan, Boyer and Jenkins',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wallace, Chambers and Leon',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Moore, White and Horn',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith, Smith and Jenkins',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Golden, Lee and Booker',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hays LLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'SeaFarms  Ltd. Liability Co Brothers',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hutchinson PLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Brown, Williams and Johnson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wu, King and Haas',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'James-Fuller',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith, Smith and Garcia',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jackson-Cox',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Kemp-Walker',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rodriguez, Williams and Guerrero',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith, Allen and Hawkins',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ross-Conner',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Collins, Lin and Lester',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Anderson, Clark and Jackson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Walker-Lozano',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rodriguez, Leon and Holt',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Price-Donaldson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Valentine-Hoover',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ramirez-Rivera',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Pitts PLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Moore, Krueger and Duncan',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones, Villa and Henderson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Bray Ltd',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ramirez-Mcfarland',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rodriguez-Scott',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Booth-Andrews',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Perry-Booth',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Banks, Shaffer and Leblanc',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Conrad Inc',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Marshall-Edwards',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Foster-Patton',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Griffin-Morrison',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Richards-Ballard',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Nash-Howard',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Perez, Ford and Collins',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mcgee PLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mason-Blankenship',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Guzman, Henderson and Lopez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Johnson, Munoz and Chavez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Whitehead, Fisher and Taylor',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Roberts, Martinez and Rodriguez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Austin, Robbins and Harris',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hester-Rodriguez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Roberts, Carter and Jones',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mckay PLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Blue Ridge   GmbH Flotsam',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Downs Ltd',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Punjab s Pic Express',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Garza, Price and Neal',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mullen-Brown',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Dixon-Marshall',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Lutz Inc',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gray-Ross',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Avery-Davis',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Schultz, Barber and Rich',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Victoria Falls   Ges.m.b.H. -',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Shields-Campbell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Klein, Rice and Garcia',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Torres-Anderson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Oliver, Wood and Phillips',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones-Chan',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Sherman, Williams and Hawkins',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Carey-Johnson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Murillo-Dickson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Paul Ltd',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Reese, Reid and Owen',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Thomas-Richards',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Martinez, Gonzales and Williams',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gardner, Jones and Stone',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hernandez-Meyers',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Williams, Howard and Smith',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wright-Jones',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mccarthy-Villanueva',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Herring-Sheppard',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Floyd-Mcdowell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Juarez-Cohen',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Acosta, Johnson and Ball',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Harrington, Holder and Turner',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Kim, Reed and Nguyen',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gallagher, Pennington and Andrade',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wallace-Mendoza',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gomez-Ortiz',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones, Mendoza and Reilly',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Volga River Sagl Logistics',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ward, Shaffer and Short',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hogan and Sons',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Graham-Peterson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Griffin Group',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Howell, Butler and Miller',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Brock-Bryant',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith-Foster',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Riddle Ltd',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith, Reed and Richard',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Reynolds-Oliver',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mar de Plata Mussel A/S Marine biology',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Leach Inc',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mitchell, Chavez and Navarro',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Peck Ltd',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'King-Hernandez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones, Turner and Roberts',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Sharp, Fowler and Scott',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Chavez, Smith and Rios',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Martin, Cantu and Henderson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Munoz, Holden and Booth',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Chapman-Jackson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones, Wilson and Fuller',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Perkins, Alvarado and Gonzalez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hudson-Bailey',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mejia, Hanson and Booth',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Parks, Andrews and Curry',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Torres, Smith and Munoz',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ward-Robinson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gray-Edwards',
#   'country': 'Unknown',
# ...
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Chavez-Williams',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Miller, Hawkins and Coleman',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ryan, Chavez and Foster',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Morse Inc',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Johnson, Roberson and Johnson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith-Moore',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Walker-Hill',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones-Walters',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Stone, Anderson and Potts',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Cabrera-Cruz',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Edwards-James',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hall-Mason',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Watson, Smith and Atkinson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Boyd-Obrien',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Albertine Rift  OJSC Transport',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ross-Austin',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Dawson, Ramirez and Hill',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Freeman-Lowe',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Phillips, James and Allen',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Herrera-Garcia',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Moore-Moody',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rivera, Smith and Scott',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Brown-Benjamin',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Cook-Turner',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Clements-Cole',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Newton-Taylor',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Riddle-Mcbride',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Herrera-Campbell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Vargas LLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Robinson, Barron and Sims',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Carrillo, Cooper and Cruz',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Lester-Snyder',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Roy-Brown',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Oneill LLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Collins-Perez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Gonzalez, Swanson and Velasquez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Parrish, Patton and Lopez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Chen, Dickerson and Guerra',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Meza Ltd',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Porter-Miller',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Erickson Group',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Lopez-Bush',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Savaneta SE Marine conservation',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Casey, Huang and Moran',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rojas, Ross and Jones',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Barton-Campbell',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Burton, Fischer and Harrison',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rodriguez-Gill',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith, Orozco and Herrera',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Dodson-Carrillo',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Collins-Marquez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Harris, Smith and Donovan',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Craig-Collins',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mathis-Payne',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Franklin, Robinson and Hill',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Wood, Mcintosh and Finley',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jackson, Torres and Fox',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Snyder-Ford',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Valencia-Haley',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Andhra Pradesh   Plc Line',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Nelson-Rivera',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Cruz-Hernandez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Sanders-Richmond',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Smith, Nielsen and Holland',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Henry, Duke and Richmond',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Yang-Thompson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Valenzuela PLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Neal, Johnson and James',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Hall, Lam and Short',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jones-Hughes',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Jenkins, Lee and Giles',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rios-Hill',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mitchell-Kaiser',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mckay, Black and Mejia',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Costa del Sol Carriers',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Horn, Thomas and Lowe',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Kennedy-Gardner',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Williams-Peters',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Morris, Edwards and Turner',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Vaughan-Gentry',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Huffman, Ramirez and Wright',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Ortega, Robinson and Gibson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Greer LLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Pugh-Levy',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Taylor-Reeves',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Frank-Garza',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Mack-Carroll',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Vincent Inc',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Pacheco-Anderson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Austin-Adams',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Sellers-Ford',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Payne-Schmitt',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Coleman, Brown and Wilkerson',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Salazar, Williams and English',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Green-Diaz',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Rich, Gray and Gates',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Peck, Barrett and Ward',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Moyer-Price',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Stephens, Warner and Frederick',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Snyder-Huffman',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Montgomery-Hoffman',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Anderson, Vega and Thomas',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Walker, Yates and Roberts',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Sanders-Martinez',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Schroeder-Allen',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Senegal River  LLC Export',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Arnold Ltd',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Price-Burton',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  {'id': 'Marquez LLC',
#   'country': 'Unknown',
#   'product_services': ['Unknown'],
#   'revenue_omu': ['Unknown'],
#   'type': {'Unknown': 1}},
#  ...]

# %%
df_all_unique_nodes = pd.DataFrame(unique_nodes + unknown_nodes)
df_all_unique_nodes
# Out:
#                                          id     country  \
# 0                                 Jones LLC          ZH
# 1                   Coleman, Hall and Lopez          ZH
# 2      Aqua Advancements Sashimi SE Express     Oceanus
# 3                 Makumba Ltd. Liability Co  Utoporiana
# 4                Taylor, Taylor and Farrell          ZH
# ...                                     ...         ...
# 51726                         Robin Bridges     Unknown
# 51727                          John Robbins     Unknown
# 51728                           Blake Baker     Unknown
# 51729                        Danielle Kelly     Unknown
# 51730                           Holly Wells     Unknown
#
#                                         product_services  \
# 0                                 [Automobiles, Unknown]
# 1              [Passenger cars, trucks, vans, and buses]
# 2      [Holding firm whose subsidiaries are engaged i...
# 3      [Car service, car parts and accessories, autom...
# 4      [Fully electric vehicles (EVs) and electric ve...
# ...                                                  ...
# 51726                                          [Unknown]
# 51727                                          [Unknown]
# 51728                                          [Unknown]
# 51729                                          [Unknown]
# 51730                                          [Unknown]
#
#                  revenue_omu  \
# 0      [None, 310612303.447]
# 1           [162734683.9969]
# 2           [115004666.6728]
# 3            [90986412.5191]
# 4            [81466666.6728]
# ...                      ...
# 51726              [Unknown]
# 51727              [Unknown]
# 51728              [Unknown]
# 51729              [Unknown]
# 51730              [Unknown]
#
#                                                     type
# 0      {'Company': 1, 'Beneficial Owner': 5, 'Company...
# 1                                         {'Company': 1}
# 2                                         {'Company': 1}
# 3                                         {'Company': 1}
# 4                                         {'Company': 1}
# ...                                                  ...
# 51726                            {'Beneficial Owner': 1}
# 51727                            {'Company Contacts': 1}
# 51728                            {'Beneficial Owner': 1}
# 51729                            {'Beneficial Owner': 1}
# 51730                            {'Beneficial Owner': 1}
#
# [51731 rows x 5 columns]

# %% [markdown]
# #### Add node attribute

# %%
src_list = list(df_links['source'])
trgt_list = list(df_links['target'])
df_all_unique_nodes['type_length'] = df_all_unique_nodes['type'].apply(lambda x: sum(list(x.values())))
df_all_unique_nodes['is_source'] = df_all_unique_nodes['id'].apply(lambda x: 1 if x in src_list else 0)
df_all_unique_nodes['is_target'] = df_all_unique_nodes['id'].apply(lambda x: 1 if x in trgt_list else 0)
df_all_unique_nodes['total_revenue'] = df_all_unique_nodes['revenue_omu'].apply(lambda x: round(sum(list(map(lambda y: 0 if (y=="Unknown" or y=="None") else int(y), x))),2))

# %%
df_all_unique_nodes['neighbor_BO']=df_all_unique_nodes['id'].apply(lambda x: len(df_links[(df_links['source']==x) & (df_links['type']=='Beneficial Owner')]))
df_all_unique_nodes['neighbor_CC']=df_all_unique_nodes['id'].apply(lambda x: len(df_links[(df_links['source']==x) & (df_links['type']=='Company Contacts')]))
df_all_unique_nodes['total_rev_per_BO'] = df_all_unique_nodes['total_revenue']/df_all_unique_nodes['neighbor_BO'].where(df_all_unique_nodes['neighbor_BO'] != 0, 1)
# Out:
# 0         62122460.6
# 1        162734683.0
# 2         57502333.0
# 3          7582201.0
# 4         81466666.0
#             ...
# 51726            0.0
# 51727            0.0
# 51728            0.0
# 51729            0.0
# 51730            0.0
# Name: total_rev_per_BO, Length: 51731, dtype: float64

# %%
df_all_unique_nodes['total_rev_per_BO'] = df_all_unique_nodes['total_rev_per_BO'].round(decimals=2)

# %%
df_all_unique_nodes
# Out:
#                                          id     country  \
# 0                                 Jones LLC          ZH
# 1                   Coleman, Hall and Lopez          ZH
# 2      Aqua Advancements Sashimi SE Express     Oceanus
# 3                 Makumba Ltd. Liability Co  Utoporiana
# 4                Taylor, Taylor and Farrell          ZH
# ...                                     ...         ...
# 51726                         Robin Bridges     Unknown
# 51727                          John Robbins     Unknown
# 51728                           Blake Baker     Unknown
# 51729                        Danielle Kelly     Unknown
# 51730                           Holly Wells     Unknown
#
#                                         product_services  \
# 0                                 [Automobiles, Unknown]
# 1              [Passenger cars, trucks, vans, and buses]
# 2      [Holding firm whose subsidiaries are engaged i...
# 3      [Car service, car parts and accessories, autom...
# 4      [Fully electric vehicles (EVs) and electric ve...
# ...                                                  ...
# 51726                                          [Unknown]
# 51727                                          [Unknown]
# 51728                                          [Unknown]
# 51729                                          [Unknown]
# 51730                                          [Unknown]
#
#                  revenue_omu  \
# 0      [None, 310612303.447]
# 1           [162734683.9969]
# 2           [115004666.6728]
# 3            [90986412.5191]
# 4            [81466666.6728]
# ...                      ...
# 51726              [Unknown]
# 51727              [Unknown]
# 51728              [Unknown]
# 51729              [Unknown]
# 51730              [Unknown]
#
#                                                     type  type_length  \
# 0      {'Company': 1, 'Beneficial Owner': 5, 'Company...           11
# 1                                         {'Company': 1}            1
# 2                                         {'Company': 1}            1
# 3                                         {'Company': 1}            1
# 4                                         {'Company': 1}            1
# ...                                                  ...          ...
# 51726                            {'Beneficial Owner': 1}            1
# 51727                            {'Company Contacts': 1}            1
# 51728                            {'Beneficial Owner': 1}            1
# 51729                            {'Beneficial Owner': 1}            1
# 51730                            {'Beneficial Owner': 1}            1
#
#        is_source  is_target  total_revenue  neighbor_BO  neighbor_CC  \
# 0              1          0      310612303            5            3
# 1              0          0      162734683            0            0
# 2              1          0      115004666            2            1
# 3              1          0       90986412           12            1
# 4              0          0       81466666            0            0
# ...          ...        ...            ...          ...          ...
# 51726          0          1              0            0            0
# 51727          0          1              0            0            0
# 51728          0          1              0            0            0
# 51729          0          1              0            0            0
# 51730          0          1              0            0            0
#
#        total_rev_per_BO
# 0            62122460.6
# 1           162734683.0
# 2            57502333.0
# 3             7582201.0
# 4            81466666.0
# ...                 ...
# 51726               0.0
# 51727               0.0
# 51728               0.0
# 51729               0.0
# 51730               0.0
#
# [51731 rows x 12 columns]

# %%
df_all_unique_nodes.to_csv("data/nodes.csv", index=False)
df_unique_links.to_csv("data/links.csv", index=False)

# %% [markdown]
# # Filtering Ocean Nodes

# %%
ocean_nodes = pd.read_csv('ocean_nodes.csv')
ocean_nodes_id = set(ocean_nodes['id'].values)
df_all_unique_nodes['is_ocean'] = df_all_unique_nodes['id'].apply(lambda x: 1 if x in ocean_nodes_id else 0)

# %% [markdown]
# # Generate Graph Dict

# %%
nodes = pd.read_csv('data/nodes.csv')
links = pd.read_csv('data/links.csv')

# %% [markdown]
# #### generate graph

# %%
connected_nodes = nodes[(nodes['is_source']==1) | (nodes['is_target']==1)]
G = nx.node_link_graph({
    'nodes': connected_nodes.to_dict('records'),
    'links': links.to_dict('records'),
    'multigraph': False,
    'graph':{},
    'directed': False
})

# %% [markdown]
# #### divide graph into disconnected subgraphs

# %%
subgraphs = list(G.subgraph(c) for c in nx.connected_components(G))
subgraphs.sort(key=len, reverse=True)

# %% [markdown]
# #### generate subgraphs dict

# %%
subgraphs_dict = [
    {
        'id': i+1,
        'graph': nx.node_link_data(g),
        'num_nodes': g.number_of_nodes(),
        'num_links': g.number_of_edges(),
        'num_ocean_nodes': sum([1 for _, d in g.nodes(data=True) if d['is_ocean'] == 1]),
        'density': round(2*sum([d['weight'] for _, _, d in g.edges(data=True)])/(g.number_of_nodes()*(g.number_of_nodes()-1)),2),
        'average_revenue': round(sum([
            r for _, d in g.nodes(data=True)
                if type(d['revenue_omu']) != float
                    for r in eval(d['revenue_omu'])
                        if type(r) != str
            ])/g.number_of_nodes(),2),
    }
    for i, g in enumerate(subgraphs)
]

# %%
# swap source and target which are converted in the wrong way during generating graph using networkx
for g in subgraphs_dict:
    df_nodes = pd.DataFrame(g['graph']['nodes'])
    for l in g['graph']['links']:
        if df_nodes[df_nodes['id'] == l['source']]['is_source'].values[0] == 0:
            s, t = l['source'], l['target']
            l['source'], l['target'] = t, s

# %%
with open('data/graphs.json', 'w') as f:
    json.dump({'graphs': subgraphs_dict}, f)

# %% [markdown]
# # Reorder Nodes
# - reordering sources and targets by hierarchical clustering algorithm

# %%
def reorder_nodes(matrix, keys):
    Z = linkage(matrix, method='average', metric='euclidean')
    dn = dendrogram(Z, no_plot=True)['leaves']
    ordered_nodes = [keys[i] for i in dn]
    
    return ordered_nodes

# %%
with open('data/graphs.json', 'r') as f:
    graphs = json.load(f)['graphs']

# %%
# reorder nodes source first, target last
for g in graphs:
    nodes = g['graph']['nodes']
    links = g['graph']['links']

    sources = set([i['source'] for i in links])
    targets = set([i['target'] for i in links])
    node_list = list(sources) + list(targets)
    
    ordered_nodes = sorted(nodes, key=lambda x: node_list.index(x['id']) if x['id'] in node_list else float('inf'))
    g['graph']['nodes'] = ordered_nodes

# %%
# reordering nodes
for g in graphs:
    nodes = g['graph']['nodes']
    links = g['graph']['links']
    src_len = len([i for i,n in enumerate(nodes) if n['is_source'] == 1])
    
    sources = nodes[:src_len]
    targets = nodes[src_len:]
    
    order = []
    
    G = nx.node_link_graph(g['graph'])
    adj_matrix = nx.adjacency_matrix(G)
    if src_len > 3 and len(targets)>2:    
        # reorder sources
        matrix = adj_matrix.todense()[:len(sources), len(sources):].tolist()
        order = reorder_nodes(matrix, [i['id'] for i in sources])
        
        matrix = adj_matrix.todense()[len(sources):, :len(sources)].tolist()
        order = order + reorder_nodes(matrix, [i['id'] for i in targets])
        ordered_nodes = sorted(nodes, key=lambda x: order.index(x['id']) if x['id'] in order else float('inf'))
        g['graph']['nodes'] = ordered_nodes
# Out:
# /var/folders/9n/0sr5b2sn26z6qnbv7h2_9b9w0000gn/T/ipykernel_1700/851936227.py:13: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   adj_matrix = nx.adjacency_matrix(G)

# %% [markdown]
# # Add similarity
# - Add similarity between two sources
# - Add maximum similarity attribute of the nodes

# %%
# add similarity between two sources
for g in graphs:
    nodes = g['graph']['nodes']
    links = g['graph']['links']
    sources = nodes[:len(set([i['source'] for i in links]))]

    for n in nodes:
        n['similarity'] = 0

    if len(sources) < 2:
        g['similarity'] = []
        continue
    
    G = nx.node_link_graph(g['graph'])
    matrix = nx.adjacency_matrix(G, weight=None).toarray()[:len(sources), len(sources):]
    similarity = []
    for i in range(len(sources)):
        for j in range(i+1, len(sources)):
            if np.count_nonzero(matrix[i] + matrix[j]) > 1:
                similarity.append([sources[i]['id'], sources[j]['id'], round(np.dot(matrix[i], matrix[j]) / np.count_nonzero(matrix[i] + matrix[j]),2)])
            else:
                similarity.append([sources[i]['id'], sources[j]['id'], 0])
            
            nodes[i]['similarity'] = similarity[-1][2] if similarity[-1][2] > nodes[i]['similarity'] else nodes[i]['similarity']
            nodes[j]['similarity'] = similarity[-1][2] if similarity[-1][2] > nodes[j]['similarity'] else nodes[j]['similarity']        
    
    g['similarity'] = similarity
# Out:
# /var/folders/9n/0sr5b2sn26z6qnbv7h2_9b9w0000gn/T/ipykernel_1700/3285573263.py:15: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   matrix = nx.adjacency_matrix(G, weight=None).toarray()[:len(sources), len(sources):]

# %%
with open('data/graphs.json', 'w') as f:
    json.dump({'graphs': graphs}, f)
